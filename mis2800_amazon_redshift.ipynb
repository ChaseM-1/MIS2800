# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaseM-1/MIS2800/blob/main/mis2800_amazon_redshift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: The Business Impact (Lyft Case Study)

# %% [markdown]
# **Lyft Video**: https://aws.amazon.com/solutions/case-studies/lyft/
#
# **Watch the Lyft video and consider the following:**
#
# 1. The Innovation: How did moving from simple data storage to a Redshift data warehouse allow Lyft to transition from "just tracking rides" to "creating new products" like Lyft Line?
#
#
# 2. Real-time vs. Strategic: Lyft uses different tools for their app (OLTP) than they do for their planning (OLAP). Why can't they just use the same database for both?

# %% [markdown]
# ## YOUR ANSWERS TO PART 1 BELOW

# %% [markdown]
# Question 1: They were able to use Redshift to get better and quicker information from databases, which let they think of key ideas to help boost profit and create new products. This led to the creation of Lyft Line, which is where if 2 people have similar routes they can ask if they would share the Lyft for half the cost, ultimetly this idea was started because of Redshift data.
#
#
# Question 2: They can not use the same database for both because OTLP and OLAP both have opposite goals. OLTP is supposed to be quick and have real-time accuracy which is why they use it in the app. OLAP is more in depth and has more analytical power, used for planning because they can be more innovative.

# %% [markdown]
# ## Part 2: The Infrastructure (AWS Skill Builder)
#
# **Instructions**
#
#
# 1.   Create a free AWS Skill Builder account https://scribehow.com/viewer/AWS_Skillbuilder_and_Eduate__Souc1HOKQbiiJnktuVgSEQ
# 2.   Complete the "Introduction" and "Architecture" modules in AWS Skill Builder. Instructions are here: https://www.loom.com/share/530dd0536c2c44729fe9a6ed26f7f162
#
# # Answer the Questions
#
# 1. Scaling the Design: In DataCamp, we practiced Normalization. In the Redshift architecture, why is "Columnar Storage" often more important for an analyst than having perfectly normalized tables? https://docs.aws.amazon.com/redshift/latest/dg/c_columnar_storage_disk_mem_mgmnt.html
#
# 2. Speed to Insight: How does the architecture of a "Leader Node" and "Compute Nodes" change how quickly a Business Intelligence report is generated?  https://docs.aws.amazon.com/redshift/latest/dg/c_high_level_system_architecture.html

# %% [markdown]
# ## YOUR ANSWERS TO PART 2 BELOW

# %% [markdown]
# Question 1: Columnar Storage is more important than perfect normalization tables because analyst view large data tables and aggregations rather than rows that normalization is designed to create.
#
# Question 2: THe leader nodes coordinates each query while the compute nodes process the data in parallel. The leader node breaks up the query into different pieces and sends them to compute nodes, which scan the results and return them quickly.

# %% [markdown]
# ## Part 3: Strategic Reflection
#
# 1. The Management Perspective: As a future business leader, how does knowing the capabilities of a tool like Redshift change the questions you would ask your data team?
#
# 2. The ETL Bridge: Reflect on the ETL process. If you were a manager at an organization, why is the "Clean and Load" phase the most critical part of your BI strategy?

# %% [markdown]
# ## YOUR ANSWERS TO PART 3 BELOW

# %% [markdown]
# Question 1: Instead of asking what the data is or what data we have, you can start asking deeper questions like what we can do to improve our analytics. It creates a more smooth understanding and eliminates a step of explaination that will no longer be needed by the data team.
#
# Question 2: The Clean and Load phase is important because it makes sure the data going into Redshift is accurate and structures in a way analysts can approve on. Without it, it could produce unreliable results, leading to wasted analyst time and bad decisions.
