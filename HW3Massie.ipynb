# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaseM-1/MIS2800/blob/main/HW3Massie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 89.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# !pip install ipython-sql
print("ipython sql install")
# Out:
# ...
# ipython sql install

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn=sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# #Excercises

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# INSERT INTO (brand_id, brand_name, brand_type, brand_budget)
# VALUES
# (1, 'Doritos', 'Snacks', 7000000),
# (2, 'AWS', 'Technology', 15000000),
# (3, 'Pepsi', 'Beverages', 2000000),
# (4, 'He_Gets_Up', 'Religious', 1000000),
# (5, 'Dr_Pepper', 'Beverages', 5000000),
# (6, 'IBM', 'Technology', 100000),
# (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) near "(": syntax error
# [SQL: INSERT INTO (brand_id, brand_name, brand_type, brand_budget)
# VALUES
# (1, 'Doritos', 'Snacks', 7000000),
# (2, 'AWS', 'Technology', 15000000),
# (3, 'Pepsi', 'Beverages', 2000000),
# (4, 'He_Gets_Up', 'Religious', 1000000),
# (5, 'Dr_Pepper', 'Beverages', 5000000),
# (6, 'IBM', 'Technology', 100000),
# (7, 'Google', 'Technology', 8000000);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# SELECT brand_name, brand_type FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# SELECT Religious FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) no such column: Religious
# [SQL: SELECT Religious FROM Marketing_Brands;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# SELECT * FROM Marketing_Brands

# %%
# %%sql
# SELECT brand_budget FROM Marketing_Brands ORDER BY DESC
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) no such column: DESC
# [SQL: SELECT brand_budget FROM Marketing_Brands ORDER BY DESC]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# # I had to add the TABLE IF NOT EXTSTS into block 1 so it would work.

# %% [markdown]
# # I had to add the INTO into block 2 so it would work.

# %% [markdown]
# # I had to add the * so it would selct ALL to fix block 3.

# %% [markdown]
# # I had to type out brand_name and brand_type after SELECT to fix block 4.

# %% [markdown]
# # I had to add Religious after SELECT to fix block 5.

# %% [markdown]
# # To fix block 9 I had to type the function while putting DESC at the end so it sorted descending.
